# %% [markdown]
# # Övningsuppgifter – Fatima Al-Murtadha
#
# ---
#
#
# # Kapitel 1 – Introduktion till maskininlärning
#
# ## Faktafrågor
#
# ### 1. Hur hänger AI, ML och DL ihop?
# Svar:
#
# ### 2. Vilka är de fyra problemkategorierna inom ML?
# Svar:
#
# ### 3a. Syftet med tränings-, validerings- och testdata
# Svar:
#
# ### 3b. Vad är k-delad korsvalidering?
# Svar:
#
# ### 3c. Vad är RMSE?
# Svar:
#
# ### 3d. Hyperparameter vs parameter
# Svar:
#
# ### 3e. Grid search och refit=True
# Svar:
#
# ### 3f. Kategorisk data (nominal, ordinal, encoding)
# Svar:
#
# ### 3g. Vad är feature engineering?
# Svar:
#
# ### 3h. Principle of parsimony
# Svar:
#
# ### 4. En modell är en förenkling av verkligheten
# Svar:
#
# ### 5. Overfitting
# Svar:
#
# ### 6. Högre är bättre i scikit-learn scoring
# Svar:
#
# ### 7. Tvärsnittsdata, tidsseriedata, paneldata
# Svar:
#
# ---
#
# ## Resonemangfrågor
#
# ### 8. Exempel på ML-tillämpningar
# Svar:
#
# ### 9. Varför negative MSE?
# Svar:
#
# ---
#
# ## Koduppgifter
#
# ### 10. Gå igenom kodexempel
# Svar:
#
# ### 11. Varför 60–20–20 proportioner?
# Svar:
#
# ---

# %% [markdown]
# # Kapitel 2 – Ett ML-projekt från början till slut
#
# ## Faktafrågor
#
# ### 1. Checklistans sju steg + iterativt arbete
# Svar:
#
# ### 2. Produktionssättning
# Svar:
#
# ### 3. Scikit-learn: principer, estimators, predictors, transformers
# Svar:
#
# ### 4. TensorFlow och Keras
# Svar:
#
# ---
#
# ## Resonemangfrågor
#
# ### 5. Kalle vs Stina – testdata
# Svar:
#
# ### 6. Varför misslyckas ML-projekt?
# Svar:
#
# ---
#
# ## Koduppgifter
#
# ### 7. Gå igenom kodexempel
# Svar:
#
# ### 8. Spara modell med joblib
# Svar:
#
# ### 9. Komplett regressionsflöde (data_01.csv)
# Svar:
#
# ### 10. Salary dataset – korsvalidering
# Svar:
#
# ### 11. mpg dataset – kategorisk data
# Svar:
#
# ### 12. Förbättra Random Forest
# Svar:
#
# ---

# %% [markdown]
# # Kapitel 3 – Regression
#
# ## Faktafrågor
#
# ### 1. Vad kännetecknar regressionsproblem?
# Svar:
#
# ### 2. RMSE, MSE, MAE
# Svar:
#
# ### 3. RMSE vs MSE
# Svar:
#
# ### 4. Gradient descent
# Svar:
#
# ### 5. Bias–variance trade-off
# Svar:
#
# ### 6. Modellöversikter
# Svar:
#
# ### 7. White box vs black box
# Svar:
#
# ### 8. Bagging vs pasting
# Svar:
#
# ---
#
# ## Resonemangfrågor
#
# ### 9. Tolka figur 3.1
# Svar:
#
# ### 10. Tolka figur 3.13 och 3.14
# Svar:
#
# ### 11. R2-score
# Svar:
#
# ---
#
# ## Koduppgifter
#
# ### 12. Gå igenom kodexempel
# Svar:
#
# ### 13. EDA på hr_employee_data.xlsx
# Svar:
#
# ### 14. Diabetes dataset – ML-flöde
# Svar:
#
# ### 15. car_price_dataset – ML + Streamlit
# Svar:
#
# ### 16. diamonds dataset – ML-flöde
# Svar:
#
# ---

# %% [markdown]
# # Kapitel 4 – Klassificering
#
# ## Faktafrågor
#
# ### 1. Vad kännetecknar klassificeringsproblem?
# Svar:
#
# ### 2. OvR och OvO
# Svar:
#
# ### 3. Utvärderingsmått
# Svar:
#
# ### 4. Precision–recall tradeoff
# Svar:
#
# ### 5. Modellöversikter
# Svar:
#
# ### 6. Feature importance i trädmodeller
# Svar:
#
# ---
#
# ## Resonemangfrågor
#
# ### 7. Precision vs recall – rättsväsendet
# Svar:
#
# ### 8. Tolka figur 4.8
# Svar:
#
# ### 9. Varför fit_transform på train?
# Svar:
#
# ---
#
# ## Koduppgifter
#
# ### 10. Gå igenom kodexempel
# Svar:
#
# ### 11. Förklara classification_report
# Svar:
#
# ### 12. Visualisera beslutsträd
# Svar:
#
# ### 13. ML-flöde på hr_employee_data.xlsx
# Svar:
#
# ### 14. Iris dataset – ML-flöde
# Svar:
#
# ### 15. MNIST – egna bilder
# Svar:
#
# ---

# %% [markdown]
# # Kapitel 5 – Dimensionsreducering
#
# ## Faktafrågor
#
# ### 1. Curse of dimensionality
# Svar:
#
# ### 2. Dimensionsreducering
# Svar:
#
# ### 3. PCA – översikt
# Svar:
#
# ### 4. Kernel PCA – utvärdering
# Svar:
#
# ---
#
# ## Resonemangfrågor
#
# ### 5. Prediktionskvalitet vs tid
# Svar:
#
# ### 6. Tolkning efter PCA
# Svar:
#
# ---
#
# ## Koduppgifter
#
# ### 7. Gå igenom kodexempel
# Svar:
#
# ### 8. Förklara PCA-koden
# Svar:
#
# ### 9. PCA på car_price_dataset
# Svar:
#
# ---

# %% [markdown]
# # Kapitel 6 – Klustring
#
# ## Faktafrågor
#
# ### 1. Vad är klustring?
# Svar:
#
# ### 2. K-means – översikt
# Svar:
#
# ---
#
# ## Resonemangfrågor
#
# ### 3. Välja antal kluster
# Svar:
#
# ### 4. Tolka figur 6.10
# Svar:
#
# ### 5. Tolka figur 6.13
# Svar:
#
# ---
#
# ## Koduppgifter
#
# ### 6. Gå igenom kodexempel
# Svar:
#
# ### 7. K-means på housing.csv
# Svar:
#
# ### 8. Klustring på hr_employee_data.xlsx
# Svar:
#
# ### 9. Klustring på 1980s classic hits
# Svar:
#
# ---

# %% [markdown]
# # Kapitel 7 – ANN
#
# ## Faktafrågor
#
# ### 1. Inspiration för ANN
# Svar:
#
# ### 2. Vad betyder “djup”?
# Svar:
#
# ### 3. Figurer 7.2–7.5 + aktiveringsfunktioner
# Svar:
#
# ### 4. Antal parametrar
# Svar:
#
# ### 5. Dropout
# Svar:
#
# ---
#
# ## Resonemangfrågor
#
# ### 6. Förklara tabell 7.1 och 7.2
# Svar:
#
# ### 7. Experimentera med playground
# Svar:
#
# ### 8. Backpropagation
# Svar:
#
# ---
#
# ## Koduppgifter
#
# ### 9. Gå igenom kodexempel
# Svar:
#
# ### 10. MNIST – ANN + tuning
# Svar:
#
# ---

# %% [markdown]
# # Kapitel 8 – CNN
#
# ## Faktafrågor
#
# ### 1. Vad krävs för CNN?
# Svar:
#
# ### 2. Tillämpningsområden
# Svar:
#
# ### 3. RGB
# Svar:
#
# ### 4. Data augmentation
# Svar:
#
# ---
#
# ## Resonemangfrågor
#
# ### 5. Förklara CNN
# Svar:
#
# ### 6. Förklara figur 8.4
# Svar:
#
# ---
#
# ## Koduppgifter
#
# ### 7. Gå igenom kodexempel
# Svar:
#
# ### 8. CIFAR-100 – CNN + tuning + transfer learning
# Svar:
#
# ### 9. Egna bilder + Streamlit
# Svar:
#
# ### 10. Teckenspråk – CNN
# Svar:
#
# ---

# %% [markdown]
# # Kapitel 9 – RNN
#
# ## Faktafrågor
#
# ### 1. Vad är RNN designade för?
# Svar:
#
# ### 2. Två RNN-arkitekturer
# Svar:
#
# ### 3. NLP och embeddings
# Svar:
#
# ---
#
# ## Resonemangfrågor
#
# ### 4. Förklara figur 9.2
# Svar:
#
# ---
#
# ## Koduppgifter
#
# ### 5. Gå igenom kodexempel
# Svar:
#
# ### 6. Fördjupning – eget dataset
# Svar:
#
# ---

# %% [markdown]
# # Kapitel 10 – Chattbottar
#
# ## Faktafrågor
#
# ### 1. Prompt engineering
# Svar:
#
# ### 2. RAG
# Svar:
#
# ### 3. Chunking och embeddings
# Svar:
#
# ---
#
# ## Resonemangfrågor
#
# ### 4. Evaluera chattbot
# Svar:
#
# ### 5. ELIZA och Turingtestet
# Svar:
#
# ### 6. Användning + risker
# Svar:
#
# ---
#
# ## Koduppgifter
#
# ### 7. Gå igenom kodexempel
# Svar:
#
# ### 8. Skapa chattbot baserad på dokument
# Svar:
