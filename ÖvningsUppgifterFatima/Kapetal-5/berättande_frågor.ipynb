# %% [markdown]
# # Kapitel 5 – Dimensionsreducering
#
# ## Faktafrågor
#
# ### 1. Curse of dimensionality
#
#
# ### 2. Dimensionsreducering
#
#
# ### 3. PCA – översikt
#
#
# ### 4. Kernel PCA – utvärdering
#
#
# ---
#
# ## Resonemangfrågor
#
# ### 5. Prediktionskvalitet vs tid
#
#
# ### 6. Tolkning efter PCA
#
#
# ---
#
# ## Koduppgifter
#
# ### 7. Gå igenom kodexempel
#
#
# ### 8. Förklara PCA-koden
#
#
# ### 9. PCA på car_price_dataset
#
#
# ---
